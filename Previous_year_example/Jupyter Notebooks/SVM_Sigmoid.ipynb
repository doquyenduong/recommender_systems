# %% [markdown]
# ### SVM with Sigmoid Kernel
# Source of code: https://stackabuse.com/implementing-svm-and-kernel-svm-with-pythons-scikit-learn/

# %%
import pandas as pd
import sklearn

# %% [markdown]
# ere we import the encoded dataset

# %%
df = pd.read_csv('Deezer_encoded_Big.csv')
df
# Out:
#          Unnamed: 0  genre_id  ts_listen  media_id  album_id  release_date  \
# 0                 0      1358    2235113       573       224          4507
# 1                 1      1366    2207566      1808       573          5016
# 2                 2        14    1421748      3158      1006          8002
# 3                 3         6    1899424     19977      1484          3457
# 4                 4         6     401913      5029      1555          5683
# ...             ...       ...        ...       ...       ...           ...
# 7558580     7558580         0    2090512    450561    150765          1302
# 7558581     7558581         0    1753932    451728    151100          8860
# 7558582     7558582         0    1772723    451824    151147          8823
# 7558583     7558583         0    1731221    451825    151147          8823
# 7558584     7558584         0    1806535    451942    151194          8866
#
# ...

# %% [markdown]
# We drop an unnnecessary column and take a sample of 1% of the dataset.

# %%
df= df.drop(columns=['Unnamed: 0'])
df
# Out:
#          genre_id  ts_listen  media_id  album_id  release_date  platform_name  \
# 0            1358    2235113       573       224          4507              1
# 1            1366    2207566      1808       573          5016              2
# 2              14    1421748      3158      1006          8002              2
# 3               6    1899424     19977      1484          3457              0
# 4               6     401913      5029      1555          5683              0
# ...           ...        ...       ...       ...           ...            ...
# 7558580         0    2090512    450561    150765          1302              1
# 7558581         0    1753932    451728    151100          8860              0
# 7558582         0    1772723    451824    151147          8823              0
# 7558583         0    1731221    451825    151147          8823              0
# 7558584         0    1806535    451942    151194          8866              0
#
# ...

# %%
df1 = df.sample(frac =0.01) 
df1
# Out:
#          genre_id  ts_listen  media_id  album_id  release_date  platform_name  \
# 1141313        25    1532875    222054     72263          7629              0
# 2391815         0     251790    438365    147150          8832              0
# 198029          0     389116    425133    143089          8797              0
# 7280548         0     317670    442000    148271          8839              0
# 4765083         1     412985     86590     25410          4802              0
# ...           ...        ...       ...       ...           ...            ...
# 6382712         6    1451257     92492     27177          4026              0
# 4107922         6     230174    273170     89858          7992              0
# 838617         59     108585     40488     12054          5584              0
# 2831592         0     374185    393070    132090          8660              0
# 613059       1433    2060663     85728     25222          7997              0
#
# ...

# %% [markdown]
# Here we split the dataset into features and label

# %%
features2 = df1.iloc[:, :-1].values
label2 = df1.iloc[:, 13].values

# %% [markdown]
# Here we split the dataset into train and validation data. We do a split of 80/20.

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test= train_test_split(features2, label2, test_size=0.20, random_state=109)

# %% [markdown]
# We define a SVM classifier and define the kernel as Sigmoid.

# %%
from sklearn.svm import SVC
svclassifier = SVC(kernel='sigmoid')
svclassifier.fit(X_train, y_train)
# Out:
# SVC(kernel='sigmoid')

# %%
y_pred = svclassifier.predict(X_test)

# %% [markdown]
# Finally, we plot the accuracy of that model. We can observe that we reached an accuracy of 69%

# %%
from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[1564 3240]
#  [3133 7181]]
#               precision    recall  f1-score   support
#
#            0       0.33      0.33      0.33      4804
#            1       0.69      0.70      0.69     10314
#
#     accuracy                           0.58     15118
#    macro avg       0.51      0.51      0.51     15118
# weighted avg       0.58      0.58      0.58     15118

# %%
from sklearn.metrics import roc_auc_score
roc_auc_score(y_test, y_pred)
# Out:
# 0.5109000772899968
